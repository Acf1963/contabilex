# %% [markdown]
# # Planeamento da Aplicação de Contabilidade
# ## Objetivos
# - Funcionar na Web
# - Funcionar no PC (Offline)
# - Stack: Django + PWA

# %%
import pandas as pd
import django
print('Ambiente configurado com sucesso!')
print(f'Django version: {django.get_version()}')
